# %% [markdown]
# <a href="https://colab.research.google.com/github/Elakkiya1802/ML-tasks/blob/main/Task9(_English_to_Tamil).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# English to Tamil Translation (Beginner NLP Project)

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# 1. Dataset (25 sentences)


english_sentences = [
    "hello", "how are you", "i am fine", "what is your name",
    "my name is ram", "good morning", "good night",
    "thank you", "welcome", "i love india",
    "i am a student", "how old are you", "i am happy",
    "where are you", "i am from india", "do you like coffee",
    "yes i like coffee", "no i do not like tea",
    "what are you doing", "i am learning nlp",
    "deep learning is powerful", "machine learning is useful",
    "i like tamil", "tamil is my language", "good bye"
]

tamil_sentences = [
    "வணக்கம்", "நீங்கள் எப்படி இருக்கிறீர்கள்", "நான் நன்றாக இருக்கிறேன்",
    "உங்கள் பெயர் என்ன", "என் பெயர் ராம்",
    "காலை வணக்கம்", "இனிய இரவு",
    "நன்றி", "வரவேற்கிறேன்", "எனக்கு இந்தியா பிடிக்கும்",
    "நான் ஒரு மாணவன்", "உங்கள் வயது என்ன", "நான் மகிழ்ச்சியாக இருக்கிறேன்",
    "நீங்கள் எங்கே இருக்கிறீர்கள்", "நான் இந்தியாவிலிருந்து வந்தவன்",
    "உங்களுக்கு காபி பிடிக்குமா", "ஆம் எனக்கு காபி பிடிக்கும்",
    "இல்லை எனக்கு டீ பிடிக்காது",
    "நீங்கள் என்ன செய்கிறீர்கள்", "நான் NLP கற்றுக்கொள்கிறேன்",
    "டீப் லெர்னிங் சக்திவாய்ந்தது",
    "மெஷின் லெர்னிங் பயனுள்ளது",
    "எனக்கு தமிழ் பிடிக்கும்",
    "தமிழ் என் மொழி", "பிரியாவிடை"
]

# Add start and end tokens to target
tamil_sentences = ["start " + s + " end" for s in tamil_sentences]

# 2. Tokenization

eng_tokenizer = Tokenizer()
tam_tokenizer = Tokenizer()

eng_tokenizer.fit_on_texts(english_sentences)
tam_tokenizer.fit_on_texts(tamil_sentences)

eng_seq = eng_tokenizer.texts_to_sequences(english_sentences)
tam_seq = tam_tokenizer.texts_to_sequences(tamil_sentences)

max_eng_len = max(len(seq) for seq in eng_seq)
max_tam_len = max(len(seq) for seq in tam_seq)

encoder_input = pad_sequences(eng_seq, maxlen=max_eng_len, padding='post')
decoder_input = pad_sequences(tam_seq, maxlen=max_tam_len, padding='post')

decoder_output = np.zeros_like(decoder_input)
decoder_output[:, :-1] = decoder_input[:, 1:]

# 3. Model Parameters

eng_vocab_size = len(eng_tokenizer.word_index) + 1
tam_vocab_size = len(tam_tokenizer.word_index) + 1
embedding_dim = 64
latent_dim = 128
# 4. Encoder
encoder_inputs = Input(shape=(None,))
enc_embed = Embedding(eng_vocab_size, embedding_dim)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
_, state_h, state_c = encoder_lstm(enc_embed)
encoder_states = [state_h, state_c]

# 5. Decoder

decoder_inputs = Input(shape=(None,))
dec_embed = Embedding(tam_vocab_size, embedding_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(dec_embed, initial_state=encoder_states)
decoder_dense = Dense(tam_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# 6. Model Compile & Train

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

model.fit(
    [encoder_input, decoder_input],
    decoder_output[..., np.newaxis],
    epochs=300,
    batch_size=4
)

# 7. Inference Models

encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

dec_outputs, state_h, state_c = decoder_lstm(
    dec_embed, initial_state=decoder_states_inputs
)
dec_states = [state_h, state_c]
dec_outputs = decoder_dense(dec_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [dec_outputs] + dec_states
)
# 8. Translation Function

reverse_tam_index = {i: w for w, i in tam_tokenizer.word_index.items()}

def translate(sentence):
    seq = eng_tokenizer.texts_to_sequences([sentence])
    seq = pad_sequences(seq, maxlen=max_eng_len, padding='post')
    states = encoder_model.predict(seq)

    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = tam_tokenizer.word_index["start"]

    result = ""

    for _ in range(max_tam_len):
        output, h, c = decoder_model.predict([target_seq] + states)
        word_index = np.argmax(output[0, -1, :])
        word = reverse_tam_index.get(word_index, "")

        if word == "end":

            break

        result += word + " "
        target_seq[0, 0] = word_index
        states = [h, c]

    return result.strip()

# 9. Test

print("English:", "good morning")
print("Tamil:", translate("good morning"))

print("English:", "i am learning nlp")
print("Tamil:", translate("i am learning nlp"))
# Out:
# Epoch 1/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 3.8539
# Epoch 2/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7011
# Epoch 3/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.9394
# Epoch 4/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4225
# Epoch 5/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2482
# Epoch 6/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1488
# Epoch 7/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1473
# Epoch 8/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9291
# Epoch 9/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9947
# Epoch 10/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9824
# Epoch 11/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8495
# Epoch 12/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8513
# Epoch 13/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8296
# Epoch 14/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8485
# Epoch 15/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7180
# Epoch 16/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7059
# Epoch 17/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7546
# Epoch 18/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6784
# Epoch 19/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6113
# Epoch 20/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6787
# Epoch 21/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6459
# Epoch 22/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6879
# Epoch 23/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5661
# Epoch 24/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5857
# Epoch 25/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.4911
# Epoch 26/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5384
# Epoch 27/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2606
# Epoch 28/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3260
# Epoch 29/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3324
# Epoch 30/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1629
# Epoch 31/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2574
# Epoch 32/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1410
# Epoch 33/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2133
# Epoch 34/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0897
# Epoch 35/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.0331
# Epoch 36/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.9995
# Epoch 37/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.9893
# Epoch 38/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.9407
# Epoch 39/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.8881
# Epoch 40/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.8037
# Epoch 41/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.7342
# Epoch 42/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7221
# Epoch 43/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6835
# Epoch 44/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6306
# Epoch 45/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5817
# Epoch 46/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6240
# Epoch 47/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6572
# Epoch 48/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6402
# Epoch 49/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4966
# Epoch 50/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4942
# Epoch 51/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4631
# Epoch 52/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3984
# Epoch 53/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3790
# Epoch 54/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3710
# Epoch 55/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3495
# Epoch 56/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3243
# Epoch 57/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3030
# Epoch 58/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2897
# Epoch 59/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2607
# Epoch 60/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2642
# Epoch 61/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2613
# Epoch 62/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2314
# Epoch 63/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2303
# Epoch 64/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2053
# Epoch 65/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2062
# Epoch 66/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2064
# Epoch 67/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2024
# Epoch 68/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1837
# Epoch 69/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1683
# Epoch 70/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1553
# Epoch 71/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1497
# Epoch 72/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1431
# Epoch 73/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1325
# Epoch 74/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1276
# Epoch 75/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1201
# Epoch 76/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1114
# Epoch 77/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1092
# Epoch 78/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1021
# Epoch 79/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0935
# Epoch 80/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0976
# Epoch 81/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0839
# Epoch 82/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0825
# Epoch 83/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0837
# Epoch 84/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0771
# Epoch 85/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0709
# Epoch 86/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0644
# Epoch 87/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0640
# Epoch 88/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0653
# Epoch 89/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0527
# Epoch 90/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0585
# Epoch 91/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0563
# Epoch 92/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0537
# Epoch 93/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0509
# Epoch 94/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0472
# Epoch 95/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0439
# Epoch 96/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0446
# Epoch 97/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0444
# Epoch 98/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0397
# Epoch 99/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0403
# Epoch 100/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0392
# Epoch 101/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0369
# Epoch 102/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0327
# Epoch 103/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0336
# Epoch 104/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0323
# Epoch 105/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0311
# Epoch 106/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0277
# Epoch 107/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0285
# Epoch 108/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0285
# Epoch 109/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0263
# Epoch 110/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0243
# Epoch 111/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0249
# Epoch 112/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0241
# Epoch 113/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0256
# Epoch 114/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0222
# Epoch 115/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0237
# Epoch 116/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0213
# Epoch 117/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0216
# Epoch 118/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0214
# Epoch 119/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0207
# Epoch 120/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0194
# Epoch 121/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0189
# Epoch 122/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0192
# Epoch 123/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0178
# Epoch 124/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0186
# Epoch 125/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0178
# Epoch 126/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0167
# Epoch 127/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0164
# Epoch 128/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0161
# Epoch 129/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0163
# Epoch 130/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0154
# Epoch 131/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0151
# Epoch 132/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0157
# Epoch 133/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0142
# Epoch 134/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0143
# Epoch 135/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0138
# Epoch 136/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0146
# Epoch 137/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0138
# Epoch 138/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0130
# Epoch 139/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0127
# Epoch 140/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0131
# Epoch 141/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0124
# Epoch 142/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0127
# Epoch 143/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0116
# Epoch 144/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0120
# Epoch 145/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0124
# Epoch 146/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0118
# Epoch 147/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0107
# Epoch 148/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0110
# Epoch 149/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0107
# Epoch 150/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0107
# Epoch 151/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0102
# Epoch 152/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0101
# Epoch 153/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0107
# Epoch 154/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0102
# Epoch 155/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0097
# Epoch 156/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0094
# Epoch 157/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0093
# Epoch 158/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0095
# Epoch 159/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0089
# Epoch 160/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0085
# Epoch 161/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0092
# Epoch 162/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0086
# Epoch 163/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0086
# Epoch 164/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0088
# Epoch 165/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0085
# Epoch 166/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0083
# Epoch 167/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0081
# Epoch 168/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0080
# Epoch 169/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0077
# Epoch 170/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0077
# Epoch 171/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0076
# Epoch 172/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0076
# Epoch 173/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0078
# Epoch 174/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0073
# Epoch 175/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0069
# Epoch 176/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0072
# Epoch 177/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0068
# Epoch 178/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0070
# Epoch 179/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0069
# Epoch 180/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0066
# Epoch 181/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0068
# Epoch 182/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0065
# Epoch 183/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0063
# Epoch 184/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0066
# Epoch 185/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0064
# Epoch 186/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0065
# Epoch 187/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0060
# Epoch 188/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0061
# Epoch 189/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0058
# Epoch 190/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0060
# Epoch 191/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0060
# Epoch 192/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0060
# Epoch 193/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0057
# Epoch 194/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0056
# Epoch 195/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0056
# Epoch 196/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0055
# Epoch 197/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0054
# Epoch 198/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0055
# Epoch 199/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0052
# Epoch 200/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0053
# Epoch 201/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0051
# Epoch 202/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0052
# Epoch 203/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0051
# Epoch 204/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0050
# Epoch 205/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0050
# Epoch 206/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0051
# Epoch 207/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0050
# Epoch 208/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0048
# Epoch 209/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0046
# Epoch 210/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0049
# Epoch 211/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0048
# Epoch 212/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0046
# Epoch 213/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0045
# Epoch 214/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0045
# Epoch 215/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0044
# Epoch 216/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0044
# Epoch 217/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0044
# Epoch 218/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0044
# Epoch 219/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0045
# Epoch 220/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0042
# Epoch 221/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0041
# Epoch 222/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0043
# Epoch 223/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0041
# Epoch 224/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0041
# Epoch 225/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0039
# Epoch 226/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0040
# Epoch 227/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0039
# Epoch 228/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0041
# Epoch 229/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0039
# Epoch 230/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0039
# Epoch 231/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0039
# Epoch 232/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0039
# Epoch 233/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0039
# Epoch 234/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0037
# Epoch 235/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0038
# Epoch 236/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0038
# Epoch 237/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0036
# Epoch 238/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0036
# Epoch 239/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0035
# Epoch 240/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0035
# Epoch 241/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0034
# Epoch 242/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0034
# Epoch 243/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0034
# Epoch 244/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0035
# Epoch 245/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0033
# Epoch 246/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0034
# Epoch 247/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0034
# Epoch 248/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0033
# Epoch 249/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031
# Epoch 250/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0032
# Epoch 251/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0032
# Epoch 252/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031
# Epoch 253/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0030
# Epoch 254/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0029
# Epoch 255/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0030
# Epoch 256/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0030
# Epoch 257/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031
# Epoch 258/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0029
# Epoch 259/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031
# Epoch 260/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0030
# Epoch 261/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027
# Epoch 262/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0030
# Epoch 263/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0029
# Epoch 264/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029
# Epoch 265/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0028
# Epoch 266/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027
# Epoch 267/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027
# Epoch 268/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027
# Epoch 269/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027
# Epoch 270/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027
# Epoch 271/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0025
# Epoch 272/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027
# Epoch 273/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0026
# Epoch 274/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0025
# Epoch 275/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0026
# Epoch 276/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0025
# Epoch 277/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0024
# Epoch 278/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0025
# Epoch 279/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025
# Epoch 280/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0024
# Epoch 281/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025
# Epoch 282/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0024
# Epoch 283/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0024
# Epoch 284/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0024
# Epoch 285/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0024
# Epoch 286/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0024
# Epoch 287/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0023
# Epoch 288/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0023
# Epoch 289/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0023
# Epoch 290/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0022
# Epoch 291/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0022
# Epoch 292/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0022
# Epoch 293/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0021
# Epoch 294/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0022
# Epoch 295/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0022
# Epoch 296/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0022
# Epoch 297/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022
# Epoch 298/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021
# Epoch 299/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021
# Epoch 300/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021
# English: good morning
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Tamil: காலை வணக்கம்
# English: i am learning nlp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Tamil: நான் nlp கற்றுக்கொள்கிறேன்
